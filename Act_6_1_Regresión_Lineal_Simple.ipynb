# %% [markdown]
# <a href="https://colab.research.google.com/github/caroSF1/Regresi-n-Lineal/blob/main/Act_6_1_Regresi%C3%B3n_Lineal_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Act 6.1 Regresión Lineal Simple México**
# ## **Carolina Solis Flores**
# ## **A01708072**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("DatosMéxico_limpios.csv", low_memory=False)
df.head()
# Out:
#    Unnamed: 0       id    scrape_id   host_id host_listings_count  \
# 0         0.0  2056638  2.02303E+13  10531228                   3
# 1         1.0  2072354  2.02303E+13  16840050                   3
# 2         2.0   696037  2.02303E+13   3531879                   4
# 3         3.0    35797  2.02303E+13    153786                   1
# 4         4.0    44616  2.02303E+13    196253                  16
#
#   host_total_listings_count  latitude  longitude accommodates bedrooms  ...  \
# 0                         7  19.35353  -99.16299            3        1  ...
# 1                         3  19.35358  -99.16948            2        1  ...
# 2                         4   19.4418  -99.18402            6        3  ...
# 3                         1  19.38283      -99.2            2        1  ...
# 4                        16  19.41162  -99.17794          2.9      1.4  ...
#
#         property_type        room_type bathrooms_text  \
# 0         Entire loft  Entire home/apt      1.5 baths
# 1  Entire guest suite  Entire home/apt         1 bath
# 2  Entire rental unit  Entire home/apt        2 baths
# 3        Entire villa  Entire home/apt         1 bath
# 4         Entire home  Entire home/apt      5.5 baths
#
#                                            amenities    price  \
# 0  ["Wifi", "Hangers", "Fire extinguisher", "Sham...   1434.0
# 1  ["Free street parking", "Cleaning products", "...    830.0
# 2  ["Wifi \u2013 38 Mbps", "Central air condition...   1469.0
# 3  ["Wifi", "Washer", "BBQ grill", "Indoor firepl...   3658.0
# 4  ["Free street parking", "Security cameras on p...  18000.0
#
#   has_availability calendar_last_scraped first_review last_review  \
# 0                t              30/03/23     03/01/14    24/06/18
# 1                t              30/03/23     01/01/14    04/11/22
# 2                t              29/03/23     31/10/12    21/12/22
# 3                t              29/03/23     31/10/12    21/12/22
# 4                t              30/03/23     09/11/11    26/03/23
#
#   instant_bookable
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f
#
# [5 rows x 72 columns]

# %% [markdown]
# # **Filtro 1**

# %%
filtro1=df[df["room_type"] == "Private room"]
filtro1
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 7             7.0        61792  2.02303E+13     299558                   2
# 16           16.0       760912  2.02303E+13    3817743                   1
# 17           17.0      2088218  2.02303E+13   10659485                   1
# 18           18.0      2093036  2.02303E+13    3083561                   1
# 21           21.0       131610  2.02303E+13     647454                   3
# ...           ...          ...          ...        ...                 ...
# 24202     24200.0  8.56474E+17  2.02303E+13  505303275                   6
# 24215     24213.0  8.53708E+17  2.02303E+13  506768013                   1
# 24217     24215.0  8.53747E+17  2.02303E+13   68325043                   1
# 24220     24218.0  8.53922E+17  2.02303E+13  506810572                   4
# 24223     24221.0  8.54225E+17  2.02303E+13  154670560                   1
#
#       host_total_listings_count     latitude     longitude accommodates  \
# 7                             3     19.41083     -99.18057            2
# 16                            1     19.40891     -99.16083            2
# 17                            2     19.34022     -99.15306            1
# 18                            2     19.44178     -99.20202            2
# 21                            4     19.35416     -99.16488            2
# ...                         ...          ...           ...          ...
# 24202                         6  19.42434331  -99.16672888            4
# 24215                         1  19.43362825   -99.1819019            2
# 24217                         1  19.42780688  -99.17142395            2
# 24220                         4  19.38511677  -99.11769287            2
# 24223                         6   19.3710885   -99.1901864            2
#
#       bedrooms  ...                property_type     room_type  \
# 7            1  ...         Private room in home  Private room
# 16           1  ...  Private room in rental unit  Private room
# 17           1  ...         Private room in home  Private room
# 18           1  ...  Private room in rental unit  Private room
# 21           1  ...                 Private room  Private room
# ...        ...  ...                          ...           ...
# 24202        1  ...  Private room in rental unit  Private room
# 24215        2  ...  Private room in rental unit  Private room
# 24217        1  ...  Private room in rental unit  Private room
# 24220        1  ...         Private room in home  Private room
# 24223        2  ...         Private room in home  Private room
#
#          bathrooms_text                                          amenities  \
# 7         1 shared bath  ["Heating - split type ductless system", "Whir...
# 16            1.5 baths  ["Wifi", "Washer", "Kitchen", "TV with standar...
# 17            1.5 baths  ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...
# 18               1 bath  ["Elevator", "Heating", "Wifi", "Washer", "Pet...
# 21       1 private bath  ["Patio or balcony", "Wifi", "Breakfast", "Lug...
# ...                 ...                                                ...
# 24202    1 private bath  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...
# 24215     1 shared bath  ["Wifi", "Patio or balcony", "Washer", "Refrig...
# 24217    1 private bath  ["Dedicated workspace", "Wifi", "Paid parking ...
# 24220     1 shared bath  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...
# 24223  2.5 shared baths  ["Luggage dropoff allowed", "Shared patio or b...
#
#         price has_availability calendar_last_scraped first_review last_review  \
# 7      1089.0                t              30/03/23     01/11/17    31/12/22
# 16      726.0                t              30/03/23     18/12/12    30/01/16
# 17      375.0                t              30/03/23     07/01/14    15/05/18
# 18     2835.0                t              29/03/23     07/01/14    15/05/18
# 21     1244.0                t              29/03/23     06/09/14    29/01/23
# ...       ...              ...                   ...          ...         ...
# 24202  1280.0                t              30/03/23     29/03/23    29/03/23
# 24215   750.0                t              30/03/23     29/03/23    29/03/23
# 24217   600.0                t              29/03/23     29/03/23    29/03/23
# 24220   251.0                t              29/03/23     29/03/23    29/03/23
# 24223   533.0                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 72 columns]

# %% [markdown]
# ## **"host acceptance rate vs host response rate"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['host_response_rate']]
Var_Dep= filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.37477387]),
#  'rank_': 1,
#  'singular_': array([2130.78251662]),
#  'intercept_': 53.24173140734537}

# %% [markdown]
# **Modelo matemático: y= 0.37477387x + 53.24173140734537**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.11940465395747701

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['host_response_rate']])
y_pred
# Out:
# array([90.71911867, 86.97137994, 53.24173141, ..., 90.71911867,
#        90.71911867, 90.71911867])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones', y_pred)
filtro1
# Out:
#        Predicciones  Unnamed: 0           id    scrape_id    host_id  \
# 7         90.719119         7.0        61792  2.02303E+13     299558
# 16        86.971380        16.0       760912  2.02303E+13    3817743
# 17        53.241731        17.0      2088218  2.02303E+13   10659485
# 18        53.241731        18.0      2093036  2.02303E+13    3083561
# 21        90.719119        21.0       131610  2.02303E+13     647454
# ...             ...         ...          ...          ...        ...
# 24202     90.719119     24200.0  8.56474E+17  2.02303E+13  505303275
# 24215     53.241731     24213.0  8.53708E+17  2.02303E+13  506768013
# 24217     90.719119     24215.0  8.53747E+17  2.02303E+13   68325043
# 24220     90.719119     24218.0  8.53922E+17  2.02303E+13  506810572
# 24223     90.719119     24221.0  8.54225E+17  2.02303E+13  154670560
#
#       host_listings_count host_total_listings_count     latitude  \
# 7                       2                         3     19.41083
# 16                      1                         1     19.40891
# 17                      1                         2     19.34022
# 18                      1                         2     19.44178
# 21                      3                         4     19.35416
# ...                   ...                       ...          ...
# 24202                   6                         6  19.42434331
# 24215                   1                         1  19.43362825
# 24217                   1                         1  19.42780688
# 24220                   4                         4  19.38511677
# 24223                   1                         6   19.3710885
#
#           longitude accommodates  ...                property_type  \
# 7         -99.18057            2  ...         Private room in home
# 16        -99.16083            2  ...  Private room in rental unit
# 17        -99.15306            1  ...         Private room in home
# 18        -99.20202            2  ...  Private room in rental unit
# 21        -99.16488            2  ...                 Private room
# ...             ...          ...  ...                          ...
# 24202  -99.16672888            4  ...  Private room in rental unit
# 24215   -99.1819019            2  ...  Private room in rental unit
# 24217  -99.17142395            2  ...  Private room in rental unit
# 24220  -99.11769287            2  ...         Private room in home
# 24223   -99.1901864            2  ...         Private room in home
#
#           room_type    bathrooms_text  \
# 7      Private room     1 shared bath
# 16     Private room         1.5 baths
# 17     Private room         1.5 baths
# 18     Private room            1 bath
# 21     Private room    1 private bath
# ...             ...               ...
# 24202  Private room    1 private bath
# 24215  Private room     1 shared bath
# 24217  Private room    1 private bath
# 24220  Private room     1 shared bath
# 24223  Private room  2.5 shared baths
#
#                                                amenities   price  \
# 7      ["Heating - split type ductless system", "Whir...  1089.0
# 16     ["Wifi", "Washer", "Kitchen", "TV with standar...   726.0
# 17     ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...   375.0
# 18     ["Elevator", "Heating", "Wifi", "Washer", "Pet...  2835.0
# 21     ["Patio or balcony", "Wifi", "Breakfast", "Lug...  1244.0
# ...                                                  ...     ...
# 24202  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...  1280.0
# 24215  ["Wifi", "Patio or balcony", "Washer", "Refrig...   750.0
# 24217  ["Dedicated workspace", "Wifi", "Paid parking ...   600.0
# 24220  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...   251.0
# 24223  ["Luggage dropoff allowed", "Shared patio or b...   533.0
#
#       has_availability calendar_last_scraped first_review last_review  \
# 7                    t              30/03/23     01/11/17    31/12/22
# 16                   t              30/03/23     18/12/12    30/01/16
# 17                   t              30/03/23     07/01/14    15/05/18
# 18                   t              29/03/23     07/01/14    15/05/18
# 21                   t              29/03/23     06/09/14    29/01/23
# ...                ...                   ...          ...         ...
# 24202                t              30/03/23     29/03/23    29/03/23
# 24215                t              30/03/23     29/03/23    29/03/23
# 24217                t              29/03/23     29/03/23    29/03/23
# 24220                t              29/03/23     29/03/23    29/03/23
# 24223                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 73 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro1)
sns.scatterplot(x='host_response_rate', y='Predicciones', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.11940465395747701

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.34554978506356654

# %% [markdown]
# ## **"host_acceptance_rate vs price"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['price']]
Var_Dep= filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-4.58252786e-06]),
#  'rank_': 1,
#  'singular_': array([2160830.20317988]),
#  'intercept_': 87.36467280534842}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 1.8359290937075556e-05

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['price']])
y_pred
# Out:
# array([87.35968243, 87.36134589, 87.36295436, ..., 87.36192329,
#        87.36352259, 87.36223032])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 2', y_pred)
filtro1
# Out:
#        Predicciones 2  Predicciones  Unnamed: 0           id    scrape_id  \
# 7           87.359682     90.719119         7.0        61792  2.02303E+13
# 16          87.361346     86.971380        16.0       760912  2.02303E+13
# 17          87.362954     53.241731        17.0      2088218  2.02303E+13
# 18          87.351681     53.241731        18.0      2093036  2.02303E+13
# 21          87.358972     90.719119        21.0       131610  2.02303E+13
# ...               ...           ...         ...          ...          ...
# 24202       87.358807     90.719119     24200.0  8.56474E+17  2.02303E+13
# 24215       87.361236     53.241731     24213.0  8.53708E+17  2.02303E+13
# 24217       87.361923     90.719119     24215.0  8.53747E+17  2.02303E+13
# 24220       87.363523     90.719119     24218.0  8.53922E+17  2.02303E+13
# 24223       87.362230     90.719119     24221.0  8.54225E+17  2.02303E+13
#
#          host_id host_listings_count host_total_listings_count     latitude  \
# 7         299558                   2                         3     19.41083
# 16       3817743                   1                         1     19.40891
# 17      10659485                   1                         2     19.34022
# 18       3083561                   1                         2     19.44178
# 21        647454                   3                         4     19.35416
# ...          ...                 ...                       ...          ...
# 24202  505303275                   6                         6  19.42434331
# 24215  506768013                   1                         1  19.43362825
# 24217   68325043                   1                         1  19.42780688
# 24220  506810572                   4                         4  19.38511677
# 24223  154670560                   1                         6   19.3710885
#
#           longitude  ...                property_type     room_type  \
# 7         -99.18057  ...         Private room in home  Private room
# 16        -99.16083  ...  Private room in rental unit  Private room
# 17        -99.15306  ...         Private room in home  Private room
# 18        -99.20202  ...  Private room in rental unit  Private room
# 21        -99.16488  ...                 Private room  Private room
# ...             ...  ...                          ...           ...
# 24202  -99.16672888  ...  Private room in rental unit  Private room
# 24215   -99.1819019  ...  Private room in rental unit  Private room
# 24217  -99.17142395  ...  Private room in rental unit  Private room
# 24220  -99.11769287  ...         Private room in home  Private room
# 24223   -99.1901864  ...         Private room in home  Private room
#
#          bathrooms_text                                          amenities  \
# 7         1 shared bath  ["Heating - split type ductless system", "Whir...
# 16            1.5 baths  ["Wifi", "Washer", "Kitchen", "TV with standar...
# 17            1.5 baths  ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...
# 18               1 bath  ["Elevator", "Heating", "Wifi", "Washer", "Pet...
# 21       1 private bath  ["Patio or balcony", "Wifi", "Breakfast", "Lug...
# ...                 ...                                                ...
# 24202    1 private bath  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...
# 24215     1 shared bath  ["Wifi", "Patio or balcony", "Washer", "Refrig...
# 24217    1 private bath  ["Dedicated workspace", "Wifi", "Paid parking ...
# 24220     1 shared bath  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...
# 24223  2.5 shared baths  ["Luggage dropoff allowed", "Shared patio or b...
#
#         price has_availability calendar_last_scraped first_review last_review  \
# 7      1089.0                t              30/03/23     01/11/17    31/12/22
# 16      726.0                t              30/03/23     18/12/12    30/01/16
# 17      375.0                t              30/03/23     07/01/14    15/05/18
# 18     2835.0                t              29/03/23     07/01/14    15/05/18
# 21     1244.0                t              29/03/23     06/09/14    29/01/23
# ...       ...              ...                   ...          ...         ...
# 24202  1280.0                t              30/03/23     29/03/23    29/03/23
# 24215   750.0                t              30/03/23     29/03/23    29/03/23
# 24217   600.0                t              29/03/23     29/03/23    29/03/23
# 24220   251.0                t              29/03/23     29/03/23    29/03/23
# 24223   533.0                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 74 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro1)
sns.scatterplot(x='price', y='Predicciones 2', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 1.8359290937075556e-05

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.004284774315769216

# %% [markdown]
# ## **"host_acceptance_rate vs number_of_reviews"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= filtro1[['number_of_reviews']]
Var_Dep= filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.18782675]),
#  'rank_': 1,
#  'singular_': array([1916.46644273]),
#  'intercept_': 84.53380977206498}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.02426172728555709

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['number_of_reviews']])
y_pred
# Out:
# array([96.17906825, 85.47294352, 85.47294352, ..., 84.53380977,
#        84.53380977, 84.53380977])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 3', y_pred)
filtro1
# Out:
#        Predicciones 3  Predicciones 2  Predicciones  Unnamed: 0           id  \
# 7           96.179068       87.359682     90.719119         7.0        61792
# 16          85.472944       87.361346     86.971380        16.0       760912
# 17          85.472944       87.362954     53.241731        17.0      2088218
# 18          84.533810       87.351681     53.241731        18.0      2093036
# 21          84.533810       87.358972     90.719119        21.0       131610
# ...               ...             ...           ...         ...          ...
# 24202       84.533810       87.358807     90.719119     24200.0  8.56474E+17
# 24215       84.533810       87.361236     53.241731     24213.0  8.53708E+17
# 24217       84.533810       87.361923     90.719119     24215.0  8.53747E+17
# 24220       84.533810       87.363523     90.719119     24218.0  8.53922E+17
# 24223       84.533810       87.362230     90.719119     24221.0  8.54225E+17
#
#          scrape_id    host_id host_listings_count host_total_listings_count  \
# 7      2.02303E+13     299558                   2                         3
# 16     2.02303E+13    3817743                   1                         1
# 17     2.02303E+13   10659485                   1                         2
# 18     2.02303E+13    3083561                   1                         2
# 21     2.02303E+13     647454                   3                         4
# ...            ...        ...                 ...                       ...
# 24202  2.02303E+13  505303275                   6                         6
# 24215  2.02303E+13  506768013                   1                         1
# 24217  2.02303E+13   68325043                   1                         1
# 24220  2.02303E+13  506810572                   4                         4
# 24223  2.02303E+13  154670560                   1                         6
#
#           latitude  ...                property_type     room_type  \
# 7         19.41083  ...         Private room in home  Private room
# 16        19.40891  ...  Private room in rental unit  Private room
# 17        19.34022  ...         Private room in home  Private room
# 18        19.44178  ...  Private room in rental unit  Private room
# 21        19.35416  ...                 Private room  Private room
# ...            ...  ...                          ...           ...
# 24202  19.42434331  ...  Private room in rental unit  Private room
# 24215  19.43362825  ...  Private room in rental unit  Private room
# 24217  19.42780688  ...  Private room in rental unit  Private room
# 24220  19.38511677  ...         Private room in home  Private room
# 24223   19.3710885  ...         Private room in home  Private room
#
#          bathrooms_text                                          amenities  \
# 7         1 shared bath  ["Heating - split type ductless system", "Whir...
# 16            1.5 baths  ["Wifi", "Washer", "Kitchen", "TV with standar...
# 17            1.5 baths  ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...
# 18               1 bath  ["Elevator", "Heating", "Wifi", "Washer", "Pet...
# 21       1 private bath  ["Patio or balcony", "Wifi", "Breakfast", "Lug...
# ...                 ...                                                ...
# 24202    1 private bath  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...
# 24215     1 shared bath  ["Wifi", "Patio or balcony", "Washer", "Refrig...
# 24217    1 private bath  ["Dedicated workspace", "Wifi", "Paid parking ...
# 24220     1 shared bath  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...
# 24223  2.5 shared baths  ["Luggage dropoff allowed", "Shared patio or b...
#
#         price has_availability calendar_last_scraped first_review last_review  \
# 7      1089.0                t              30/03/23     01/11/17    31/12/22
# 16      726.0                t              30/03/23     18/12/12    30/01/16
# 17      375.0                t              30/03/23     07/01/14    15/05/18
# 18     2835.0                t              29/03/23     07/01/14    15/05/18
# 21     1244.0                t              29/03/23     06/09/14    29/01/23
# ...       ...              ...                   ...          ...         ...
# 24202  1280.0                t              30/03/23     29/03/23    29/03/23
# 24215   750.0                t              30/03/23     29/03/23    29/03/23
# 24217   600.0                t              29/03/23     29/03/23    29/03/23
# 24220   251.0                t              29/03/23     29/03/23    29/03/23
# 24223   533.0                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 75 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro1)
sns.scatterplot(x='number_of_reviews', y='Predicciones 3', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.02426172728555709

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.1557617645173458

# %% [markdown]
# ## **"review scores location vs review scores cleanliness"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['review_scores_cleanliness']]
Var_Dep= filtro1['review_scores_location']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.30167681]),
#  'rank_': 1,
#  'singular_': array([14.49010041]),
#  'intercept_': 3.435188382944107}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.1746334930412634

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['review_scores_cleanliness']])
y_pred
# Out:
# array([4.91340474, 4.88323706, 4.8229017 , ..., 4.85306938, 4.85306938,
#        4.85306938])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 4', y_pred)
filtro1
# Out:
#        Predicciones 4  Predicciones 3  Predicciones 2  Predicciones  \
# 7            4.913405       96.179068       87.359682     90.719119
# 16           4.883237       85.472944       87.361346     86.971380
# 17           4.822902       85.472944       87.362954     53.241731
# 18           4.853069       84.533810       87.351681     53.241731
# 21           4.853069       84.533810       87.358972     90.719119
# ...               ...             ...             ...           ...
# 24202        4.853069       84.533810       87.358807     90.719119
# 24215        4.853069       84.533810       87.361236     53.241731
# 24217        4.853069       84.533810       87.361923     90.719119
# 24220        4.853069       84.533810       87.363523     90.719119
# 24223        4.853069       84.533810       87.362230     90.719119
#
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 7             7.0        61792  2.02303E+13     299558                   2
# 16           16.0       760912  2.02303E+13    3817743                   1
# 17           17.0      2088218  2.02303E+13   10659485                   1
# 18           18.0      2093036  2.02303E+13    3083561                   1
# 21           21.0       131610  2.02303E+13     647454                   3
# ...           ...          ...          ...        ...                 ...
# 24202     24200.0  8.56474E+17  2.02303E+13  505303275                   6
# 24215     24213.0  8.53708E+17  2.02303E+13  506768013                   1
# 24217     24215.0  8.53747E+17  2.02303E+13   68325043                   1
# 24220     24218.0  8.53922E+17  2.02303E+13  506810572                   4
# 24223     24221.0  8.54225E+17  2.02303E+13  154670560                   1
#
#       host_total_listings_count  ...                property_type  \
# 7                             3  ...         Private room in home
# 16                            1  ...  Private room in rental unit
# 17                            2  ...         Private room in home
# 18                            2  ...  Private room in rental unit
# 21                            4  ...                 Private room
# ...                         ...  ...                          ...
# 24202                         6  ...  Private room in rental unit
# 24215                         1  ...  Private room in rental unit
# 24217                         1  ...  Private room in rental unit
# 24220                         4  ...         Private room in home
# 24223                         6  ...         Private room in home
#
#           room_type    bathrooms_text  \
# 7      Private room     1 shared bath
# 16     Private room         1.5 baths
# 17     Private room         1.5 baths
# 18     Private room            1 bath
# 21     Private room    1 private bath
# ...             ...               ...
# 24202  Private room    1 private bath
# 24215  Private room     1 shared bath
# 24217  Private room    1 private bath
# 24220  Private room     1 shared bath
# 24223  Private room  2.5 shared baths
#
#                                                amenities   price  \
# 7      ["Heating - split type ductless system", "Whir...  1089.0
# 16     ["Wifi", "Washer", "Kitchen", "TV with standar...   726.0
# 17     ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...   375.0
# 18     ["Elevator", "Heating", "Wifi", "Washer", "Pet...  2835.0
# 21     ["Patio or balcony", "Wifi", "Breakfast", "Lug...  1244.0
# ...                                                  ...     ...
# 24202  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...  1280.0
# 24215  ["Wifi", "Patio or balcony", "Washer", "Refrig...   750.0
# 24217  ["Dedicated workspace", "Wifi", "Paid parking ...   600.0
# 24220  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...   251.0
# 24223  ["Luggage dropoff allowed", "Shared patio or b...   533.0
#
#       has_availability calendar_last_scraped first_review last_review  \
# 7                    t              30/03/23     01/11/17    31/12/22
# 16                   t              30/03/23     18/12/12    30/01/16
# 17                   t              30/03/23     07/01/14    15/05/18
# 18                   t              29/03/23     07/01/14    15/05/18
# 21                   t              29/03/23     06/09/14    29/01/23
# ...                ...                   ...          ...         ...
# 24202                t              30/03/23     29/03/23    29/03/23
# 24215                t              30/03/23     29/03/23    29/03/23
# 24217                t              29/03/23     29/03/23    29/03/23
# 24220                t              29/03/23     29/03/23    29/03/23
# 24223                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 76 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro1)
sns.scatterplot(x='review_scores_cleanliness', y='Predicciones 4', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.1746334930412634

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.417891724064097

# %% [markdown]
# ## **"availability_365 vs number _of reviews"**

# %%
filtro1.availability_365 = filtro1.availability_365.astype(str)
# Out:
# <ipython-input-529-b6f2c2b9c89b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro1.availability_365 = filtro1.availability_365.astype(str)

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['number_of_reviews']]
Var_Dep= filtro1['availability_365']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.42562581]),
#  'rank_': 1,
#  'singular_': array([1916.46644273]),
#  'intercept_': 259.4609301417107}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.005180477985288978

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['number_of_reviews']])
y_pred
# Out:
# array([233.07212987, 257.33280109, 257.33280109, ..., 259.46093014,
#        259.46093014, 259.46093014])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 5', y_pred)
filtro1
# Out:
#        Predicciones 5  Predicciones 4  Predicciones 3  Predicciones 2  \
# 7          233.072130        4.913405       96.179068       87.359682
# 16         257.332801        4.883237       85.472944       87.361346
# 17         257.332801        4.822902       85.472944       87.362954
# 18         259.460930        4.853069       84.533810       87.351681
# 21         259.460930        4.853069       84.533810       87.358972
# ...               ...             ...             ...             ...
# 24202      259.460930        4.853069       84.533810       87.358807
# 24215      259.460930        4.853069       84.533810       87.361236
# 24217      259.460930        4.853069       84.533810       87.361923
# 24220      259.460930        4.853069       84.533810       87.363523
# 24223      259.460930        4.853069       84.533810       87.362230
#
#        Predicciones  Unnamed: 0           id    scrape_id    host_id  \
# 7         90.719119         7.0        61792  2.02303E+13     299558
# 16        86.971380        16.0       760912  2.02303E+13    3817743
# 17        53.241731        17.0      2088218  2.02303E+13   10659485
# 18        53.241731        18.0      2093036  2.02303E+13    3083561
# 21        90.719119        21.0       131610  2.02303E+13     647454
# ...             ...         ...          ...          ...        ...
# 24202     90.719119     24200.0  8.56474E+17  2.02303E+13  505303275
# 24215     53.241731     24213.0  8.53708E+17  2.02303E+13  506768013
# 24217     90.719119     24215.0  8.53747E+17  2.02303E+13   68325043
# 24220     90.719119     24218.0  8.53922E+17  2.02303E+13  506810572
# 24223     90.719119     24221.0  8.54225E+17  2.02303E+13  154670560
#
#       host_listings_count  ...                property_type     room_type  \
# 7                       2  ...         Private room in home  Private room
# 16                      1  ...  Private room in rental unit  Private room
# 17                      1  ...         Private room in home  Private room
# 18                      1  ...  Private room in rental unit  Private room
# 21                      3  ...                 Private room  Private room
# ...                   ...  ...                          ...           ...
# 24202                   6  ...  Private room in rental unit  Private room
# 24215                   1  ...  Private room in rental unit  Private room
# 24217                   1  ...  Private room in rental unit  Private room
# 24220                   4  ...         Private room in home  Private room
# 24223                   1  ...         Private room in home  Private room
#
#          bathrooms_text                                          amenities  \
# 7         1 shared bath  ["Heating - split type ductless system", "Whir...
# 16            1.5 baths  ["Wifi", "Washer", "Kitchen", "TV with standar...
# 17            1.5 baths  ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...
# 18               1 bath  ["Elevator", "Heating", "Wifi", "Washer", "Pet...
# 21       1 private bath  ["Patio or balcony", "Wifi", "Breakfast", "Lug...
# ...                 ...                                                ...
# 24202    1 private bath  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...
# 24215     1 shared bath  ["Wifi", "Patio or balcony", "Washer", "Refrig...
# 24217    1 private bath  ["Dedicated workspace", "Wifi", "Paid parking ...
# 24220     1 shared bath  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...
# 24223  2.5 shared baths  ["Luggage dropoff allowed", "Shared patio or b...
#
#         price has_availability calendar_last_scraped first_review last_review  \
# 7      1089.0                t              30/03/23     01/11/17    31/12/22
# 16      726.0                t              30/03/23     18/12/12    30/01/16
# 17      375.0                t              30/03/23     07/01/14    15/05/18
# 18     2835.0                t              29/03/23     07/01/14    15/05/18
# 21     1244.0                t              29/03/23     06/09/14    29/01/23
# ...       ...              ...                   ...          ...         ...
# 24202  1280.0                t              30/03/23     29/03/23    29/03/23
# 24215   750.0                t              30/03/23     29/03/23    29/03/23
# 24217   600.0                t              29/03/23     29/03/23    29/03/23
# 24220   251.0                t              29/03/23     29/03/23    29/03/23
# 24223   533.0                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 77 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro1)
sns.scatterplot(x='number_of_reviews', y='Predicciones 5', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.005180477985288978

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.07197553740882369

# %% [markdown]
# ## **"reviews_per_month vs review_scores_communication"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['review_scores_communication']]
Var_Dep= filtro1['reviews_per_month']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-2.12770292]),
#  'rank_': 1,
#  'singular_': array([10.54343773]),
#  'intercept_': 11.541894914308859}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.07275374030333959

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['review_scores_communication']])
y_pred
# Out:
# array([1.00976545, 1.75446147, 1.32892089, ..., 1.32892089, 1.32892089,
#        1.32892089])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 6', y_pred)
filtro1
# Out:
#        Predicciones 6  Predicciones 5  Predicciones 4  Predicciones 3  \
# 7            1.009765      233.072130        4.913405       96.179068
# 16           1.754461      257.332801        4.883237       85.472944
# 17           1.328921      257.332801        4.822902       85.472944
# 18           1.328921      259.460930        4.853069       84.533810
# 21           1.328921      259.460930        4.853069       84.533810
# ...               ...             ...             ...             ...
# 24202        1.328921      259.460930        4.853069       84.533810
# 24215        1.328921      259.460930        4.853069       84.533810
# 24217        1.328921      259.460930        4.853069       84.533810
# 24220        1.328921      259.460930        4.853069       84.533810
# 24223        1.328921      259.460930        4.853069       84.533810
#
#        Predicciones 2  Predicciones  Unnamed: 0           id    scrape_id  \
# 7           87.359682     90.719119         7.0        61792  2.02303E+13
# 16          87.361346     86.971380        16.0       760912  2.02303E+13
# 17          87.362954     53.241731        17.0      2088218  2.02303E+13
# 18          87.351681     53.241731        18.0      2093036  2.02303E+13
# 21          87.358972     90.719119        21.0       131610  2.02303E+13
# ...               ...           ...         ...          ...          ...
# 24202       87.358807     90.719119     24200.0  8.56474E+17  2.02303E+13
# 24215       87.361236     53.241731     24213.0  8.53708E+17  2.02303E+13
# 24217       87.361923     90.719119     24215.0  8.53747E+17  2.02303E+13
# 24220       87.363523     90.719119     24218.0  8.53922E+17  2.02303E+13
# 24223       87.362230     90.719119     24221.0  8.54225E+17  2.02303E+13
#
#          host_id  ...                property_type     room_type  \
# 7         299558  ...         Private room in home  Private room
# 16       3817743  ...  Private room in rental unit  Private room
# 17      10659485  ...         Private room in home  Private room
# 18       3083561  ...  Private room in rental unit  Private room
# 21        647454  ...                 Private room  Private room
# ...          ...  ...                          ...           ...
# 24202  505303275  ...  Private room in rental unit  Private room
# 24215  506768013  ...  Private room in rental unit  Private room
# 24217   68325043  ...  Private room in rental unit  Private room
# 24220  506810572  ...         Private room in home  Private room
# 24223  154670560  ...         Private room in home  Private room
#
#          bathrooms_text                                          amenities  \
# 7         1 shared bath  ["Heating - split type ductless system", "Whir...
# 16            1.5 baths  ["Wifi", "Washer", "Kitchen", "TV with standar...
# 17            1.5 baths  ["Wifi", "Iron", "Washer", "Pets allowed", "Ha...
# 18               1 bath  ["Elevator", "Heating", "Wifi", "Washer", "Pet...
# 21       1 private bath  ["Patio or balcony", "Wifi", "Breakfast", "Lug...
# ...                 ...                                                ...
# 24202    1 private bath  ["Smoke alarm", "Wifi", "Hot tub", "Washer", "...
# 24215     1 shared bath  ["Wifi", "Patio or balcony", "Washer", "Refrig...
# 24217    1 private bath  ["Dedicated workspace", "Wifi", "Paid parking ...
# 24220     1 shared bath  ["Wifi", "Washer", "Pets allowed", "Outdoor sh...
# 24223  2.5 shared baths  ["Luggage dropoff allowed", "Shared patio or b...
#
#         price has_availability calendar_last_scraped first_review last_review  \
# 7      1089.0                t              30/03/23     01/11/17    31/12/22
# 16      726.0                t              30/03/23     18/12/12    30/01/16
# 17      375.0                t              30/03/23     07/01/14    15/05/18
# 18     2835.0                t              29/03/23     07/01/14    15/05/18
# 21     1244.0                t              29/03/23     06/09/14    29/01/23
# ...       ...              ...                   ...          ...         ...
# 24202  1280.0                t              30/03/23     29/03/23    29/03/23
# 24215   750.0                t              30/03/23     29/03/23    29/03/23
# 24217   600.0                t              29/03/23     29/03/23    29/03/23
# 24220   251.0                t              29/03/23     29/03/23    29/03/23
# 24223   533.0                t              29/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 7                    f
# 16                   f
# 17                   f
# 18                   f
# 21                   f
# ...                ...
# 24202                t
# 24215                f
# 24217                f
# 24220                t
# 24223                f
#
# [8201 rows x 78 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro1)
sns.scatterplot(x='review_scores_communication', y='Predicciones 6', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.07275374030333959

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.2697290127208039

# %% [markdown]
# # **Filtro 2**

# %%
filtro2=df[df["room_type"] == "Entire home/apt"]
filtro2
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 1             1.0      2072354  2.02303E+13   16840050                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# ...           ...          ...          ...        ...                 ...
# 24219     24217.0   8.5379E+17  2.02303E+13   29239005                   3
# 24221     24219.0  8.53924E+17  2.02303E+13  488030249                   3
# 24222     24220.0  8.53967E+17  2.02303E+13  506816029                   1
# 24224     24222.0  8.54248E+17  2.02303E+13    7799414                  13
# 24225     24223.0   8.5426E+17  2.02303E+13  506864314                   2
#
#       host_total_listings_count     latitude     longitude accommodates  \
# 0                             7     19.35353     -99.16299            3
# 1                             3     19.35358     -99.16948            2
# 2                             4      19.4418     -99.18402            6
# 3                             1     19.38283         -99.2            2
# 4                            16     19.41162     -99.17794          2.9
# ...                         ...          ...           ...          ...
# 24219                         3  19.41121012  -99.17416094            2
# 24221                         4  19.39666335  -99.14814491            2
# 24222                         1  19.39202345  -99.11872158            7
# 24224                        13   19.4037919   -99.1649783            2
# 24225                         2  19.42628282  -99.17560335            6
#
#       bedrooms  ...       property_type        room_type bathrooms_text  \
# 0            1  ...         Entire loft  Entire home/apt      1.5 baths
# 1            1  ...  Entire guest suite  Entire home/apt         1 bath
# 2            3  ...  Entire rental unit  Entire home/apt        2 baths
# 3            1  ...        Entire villa  Entire home/apt         1 bath
# 4          1.4  ...         Entire home  Entire home/apt      5.5 baths
# ...        ...  ...                 ...              ...            ...
# 24219        1  ...  Entire rental unit  Entire home/apt         1 bath
# 24221        1  ...  Entire rental unit  Entire home/apt         1 bath
# 24222        2  ...  Entire rental unit  Entire home/apt         1 bath
# 24224        1  ...  Entire rental unit  Entire home/apt         1 bath
# 24225        3  ...  Entire rental unit  Entire home/apt         1 bath
#
#                                                amenities    price  \
# 0      ["Wifi", "Hangers", "Fire extinguisher", "Sham...   1434.0
# 1      ["Free street parking", "Cleaning products", "...    830.0
# 2      ["Wifi \u2013 38 Mbps", "Central air condition...   1469.0
# 3      ["Wifi", "Washer", "BBQ grill", "Indoor firepl...   3658.0
# 4      ["Free street parking", "Security cameras on p...  18000.0
# ...                                                  ...      ...
# 24219  ["Clothing storage: closet and dresser", "Smok...    980.0
# 24221  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...    760.0
# 24222  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...   1520.0
# 24224  ["Smoke alarm", "Free street parking", "Condit...   1200.0
# 24225  ["Long term stays allowed", "Cleaning products...   1720.0
#
#       has_availability calendar_last_scraped first_review last_review  \
# 0                    t              30/03/23     03/01/14    24/06/18
# 1                    t              30/03/23     01/01/14    04/11/22
# 2                    t              29/03/23     31/10/12    21/12/22
# 3                    t              29/03/23     31/10/12    21/12/22
# 4                    t              30/03/23     09/11/11    26/03/23
# ...                ...                   ...          ...         ...
# 24219                t              29/03/23     29/03/23    29/03/23
# 24221                t              30/03/23     29/03/23    29/03/23
# 24222                t              29/03/23     29/03/23    29/03/23
# 24224                t              30/03/23     29/03/23    29/03/23
# 24225                t              30/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 0                    f
# 1                    f
# 2                    f
# 3                    f
# 4                    f
# ...                ...
# 24219                t
# 24221                f
# 24222                t
# 24224                t
# 24225                t
#
# [15601 rows x 72 columns]

# %% [markdown]
# ## **"host acceptance rate vs host response rate"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro2)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['host_response_rate']]
Var_Dep= filtro2['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.43277769]),
#  'rank_': 1,
#  'singular_': array([1791.02729985]),
#  'intercept_': 51.779740231738785}

# %% [markdown]
# **Modelo matemático: y= 0.37477387x + 53.24173140734537**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.12074513808012433

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['host_response_rate']])
y_pred
# Out:
# array([95.05750961, 95.05750961, 95.05750961, ..., 95.05750961,
#        95.05750961, 95.05750961])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones', y_pred)
filtro2
# Out:
#        Predicciones  Unnamed: 0           id    scrape_id    host_id  \
# 0          95.05751         0.0      2056638  2.02303E+13   10531228
# 1          95.05751         1.0      2072354  2.02303E+13   16840050
# 2          95.05751         2.0       696037  2.02303E+13    3531879
# 3          95.05751         3.0        35797  2.02303E+13     153786
# 4          95.05751         4.0        44616  2.02303E+13     196253
# ...             ...         ...          ...          ...        ...
# 24219      95.05751     24217.0   8.5379E+17  2.02303E+13   29239005
# 24221      95.05751     24219.0  8.53924E+17  2.02303E+13  488030249
# 24222      95.05751     24220.0  8.53967E+17  2.02303E+13  506816029
# 24224      95.05751     24222.0  8.54248E+17  2.02303E+13    7799414
# 24225      95.05751     24223.0   8.5426E+17  2.02303E+13  506864314
#
#       host_listings_count host_total_listings_count     latitude  \
# 0                       3                         7     19.35353
# 1                       3                         3     19.35358
# 2                       4                         4      19.4418
# 3                       1                         1     19.38283
# 4                      16                        16     19.41162
# ...                   ...                       ...          ...
# 24219                   3                         3  19.41121012
# 24221                   3                         4  19.39666335
# 24222                   1                         1  19.39202345
# 24224                  13                        13   19.4037919
# 24225                   2                         2  19.42628282
#
#           longitude accommodates  ...       property_type        room_type  \
# 0         -99.16299            3  ...         Entire loft  Entire home/apt
# 1         -99.16948            2  ...  Entire guest suite  Entire home/apt
# 2         -99.18402            6  ...  Entire rental unit  Entire home/apt
# 3             -99.2            2  ...        Entire villa  Entire home/apt
# 4         -99.17794          2.9  ...         Entire home  Entire home/apt
# ...             ...          ...  ...                 ...              ...
# 24219  -99.17416094            2  ...  Entire rental unit  Entire home/apt
# 24221  -99.14814491            2  ...  Entire rental unit  Entire home/apt
# 24222  -99.11872158            7  ...  Entire rental unit  Entire home/apt
# 24224   -99.1649783            2  ...  Entire rental unit  Entire home/apt
# 24225  -99.17560335            6  ...  Entire rental unit  Entire home/apt
#
#       bathrooms_text                                          amenities  \
# 0          1.5 baths  ["Wifi", "Hangers", "Fire extinguisher", "Sham...
# 1             1 bath  ["Free street parking", "Cleaning products", "...
# 2            2 baths  ["Wifi \u2013 38 Mbps", "Central air condition...
# 3             1 bath  ["Wifi", "Washer", "BBQ grill", "Indoor firepl...
# 4          5.5 baths  ["Free street parking", "Security cameras on p...
# ...              ...                                                ...
# 24219         1 bath  ["Clothing storage: closet and dresser", "Smok...
# 24221         1 bath  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...
# 24222         1 bath  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...
# 24224         1 bath  ["Smoke alarm", "Free street parking", "Condit...
# 24225         1 bath  ["Long term stays allowed", "Cleaning products...
#
#          price has_availability calendar_last_scraped first_review  \
# 0       1434.0                t              30/03/23     03/01/14
# 1        830.0                t              30/03/23     01/01/14
# 2       1469.0                t              29/03/23     31/10/12
# 3       3658.0                t              29/03/23     31/10/12
# 4      18000.0                t              30/03/23     09/11/11
# ...        ...              ...                   ...          ...
# 24219    980.0                t              29/03/23     29/03/23
# 24221    760.0                t              30/03/23     29/03/23
# 24222   1520.0                t              29/03/23     29/03/23
# 24224   1200.0                t              30/03/23     29/03/23
# 24225   1720.0                t              30/03/23     29/03/23
#
#       last_review instant_bookable
# 0        24/06/18                f
# 1        04/11/22                f
# 2        21/12/22                f
# 3        21/12/22                f
# 4        26/03/23                f
# ...           ...              ...
# 24219    29/03/23                t
# 24221    29/03/23                f
# 24222    29/03/23                t
# 24224    29/03/23                t
# 24225    29/03/23                t
#
# [15601 rows x 73 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro2)
sns.scatterplot(x='host_response_rate', y='Predicciones', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.12074513808012433

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.347484011258251

# %% [markdown]
# ## **"host_acceptance_rate vs price"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro2)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['price']]
Var_Dep= filtro2['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([3.4680127e-06]),
#  'rank_': 1,
#  'singular_': array([1828454.48919382]),
#  'intercept_': 93.48952506214029}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 8.081001223292361e-06

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['price']])
y_pred
# Out:
# array([93.49449819, 93.49240351, 93.49461957, ..., 93.49479644,
#        93.49368668, 93.49549004])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 2', y_pred)
filtro2
# Out:
#        Predicciones 2  Predicciones  Unnamed: 0           id    scrape_id  \
# 0           93.494498      95.05751         0.0      2056638  2.02303E+13
# 1           93.492404      95.05751         1.0      2072354  2.02303E+13
# 2           93.494620      95.05751         2.0       696037  2.02303E+13
# 3           93.502211      95.05751         3.0        35797  2.02303E+13
# 4           93.551949      95.05751         4.0        44616  2.02303E+13
# ...               ...           ...         ...          ...          ...
# 24219       93.492924      95.05751     24217.0   8.5379E+17  2.02303E+13
# 24221       93.492161      95.05751     24219.0  8.53924E+17  2.02303E+13
# 24222       93.494796      95.05751     24220.0  8.53967E+17  2.02303E+13
# 24224       93.493687      95.05751     24222.0  8.54248E+17  2.02303E+13
# 24225       93.495490      95.05751     24223.0   8.5426E+17  2.02303E+13
#
#          host_id host_listings_count host_total_listings_count     latitude  \
# 0       10531228                   3                         7     19.35353
# 1       16840050                   3                         3     19.35358
# 2        3531879                   4                         4      19.4418
# 3         153786                   1                         1     19.38283
# 4         196253                  16                        16     19.41162
# ...          ...                 ...                       ...          ...
# 24219   29239005                   3                         3  19.41121012
# 24221  488030249                   3                         4  19.39666335
# 24222  506816029                   1                         1  19.39202345
# 24224    7799414                  13                        13   19.4037919
# 24225  506864314                   2                         2  19.42628282
#
#           longitude  ...       property_type        room_type bathrooms_text  \
# 0         -99.16299  ...         Entire loft  Entire home/apt      1.5 baths
# 1         -99.16948  ...  Entire guest suite  Entire home/apt         1 bath
# 2         -99.18402  ...  Entire rental unit  Entire home/apt        2 baths
# 3             -99.2  ...        Entire villa  Entire home/apt         1 bath
# 4         -99.17794  ...         Entire home  Entire home/apt      5.5 baths
# ...             ...  ...                 ...              ...            ...
# 24219  -99.17416094  ...  Entire rental unit  Entire home/apt         1 bath
# 24221  -99.14814491  ...  Entire rental unit  Entire home/apt         1 bath
# 24222  -99.11872158  ...  Entire rental unit  Entire home/apt         1 bath
# 24224   -99.1649783  ...  Entire rental unit  Entire home/apt         1 bath
# 24225  -99.17560335  ...  Entire rental unit  Entire home/apt         1 bath
#
#                                                amenities    price  \
# 0      ["Wifi", "Hangers", "Fire extinguisher", "Sham...   1434.0
# 1      ["Free street parking", "Cleaning products", "...    830.0
# 2      ["Wifi \u2013 38 Mbps", "Central air condition...   1469.0
# 3      ["Wifi", "Washer", "BBQ grill", "Indoor firepl...   3658.0
# 4      ["Free street parking", "Security cameras on p...  18000.0
# ...                                                  ...      ...
# 24219  ["Clothing storage: closet and dresser", "Smok...    980.0
# 24221  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...    760.0
# 24222  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...   1520.0
# 24224  ["Smoke alarm", "Free street parking", "Condit...   1200.0
# 24225  ["Long term stays allowed", "Cleaning products...   1720.0
#
#       has_availability calendar_last_scraped first_review last_review  \
# 0                    t              30/03/23     03/01/14    24/06/18
# 1                    t              30/03/23     01/01/14    04/11/22
# 2                    t              29/03/23     31/10/12    21/12/22
# 3                    t              29/03/23     31/10/12    21/12/22
# 4                    t              30/03/23     09/11/11    26/03/23
# ...                ...                   ...          ...         ...
# 24219                t              29/03/23     29/03/23    29/03/23
# 24221                t              30/03/23     29/03/23    29/03/23
# 24222                t              29/03/23     29/03/23    29/03/23
# 24224                t              30/03/23     29/03/23    29/03/23
# 24225                t              30/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 0                    f
# 1                    f
# 2                    f
# 3                    f
# 4                    f
# ...                ...
# 24219                t
# 24221                f
# 24222                t
# 24224                t
# 24225                t
#
# [15601 rows x 74 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro2)
sns.scatterplot(x='price', y='Predicciones 2', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 8.081001223292361e-06

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.0028427101898175202

# %% [markdown]
# ## **"host_acceptance_rate vs number_of_reviews"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro2)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= filtro2[['number_of_reviews']]
Var_Dep= filtro2['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.10163592]),
#  'rank_': 1,
#  'singular_': array([3043.24765506]),
#  'intercept_': 91.14472561727152}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.019226689619606607

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['number_of_reviews']])
y_pred
# Out:
# array([93.27907987, 97.34451655, 95.10852638, ..., 91.14472562,
#        91.14472562, 91.14472562])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 3', y_pred)
filtro2
# Out:
#        Predicciones 3  Predicciones 2  Predicciones  Unnamed: 0           id  \
# 0           93.279080       93.494498      95.05751         0.0      2056638
# 1           97.344517       93.492404      95.05751         1.0      2072354
# 2           95.108526       93.494620      95.05751         2.0       696037
# 3           91.144726       93.502211      95.05751         3.0        35797
# 4           97.649424       93.551949      95.05751         4.0        44616
# ...               ...             ...           ...         ...          ...
# 24219       91.144726       93.492924      95.05751     24217.0   8.5379E+17
# 24221       91.144726       93.492161      95.05751     24219.0  8.53924E+17
# 24222       91.144726       93.494796      95.05751     24220.0  8.53967E+17
# 24224       91.144726       93.493687      95.05751     24222.0  8.54248E+17
# 24225       91.144726       93.495490      95.05751     24223.0   8.5426E+17
#
#          scrape_id    host_id host_listings_count host_total_listings_count  \
# 0      2.02303E+13   10531228                   3                         7
# 1      2.02303E+13   16840050                   3                         3
# 2      2.02303E+13    3531879                   4                         4
# 3      2.02303E+13     153786                   1                         1
# 4      2.02303E+13     196253                  16                        16
# ...            ...        ...                 ...                       ...
# 24219  2.02303E+13   29239005                   3                         3
# 24221  2.02303E+13  488030249                   3                         4
# 24222  2.02303E+13  506816029                   1                         1
# 24224  2.02303E+13    7799414                  13                        13
# 24225  2.02303E+13  506864314                   2                         2
#
#           latitude  ...       property_type        room_type bathrooms_text  \
# 0         19.35353  ...         Entire loft  Entire home/apt      1.5 baths
# 1         19.35358  ...  Entire guest suite  Entire home/apt         1 bath
# 2          19.4418  ...  Entire rental unit  Entire home/apt        2 baths
# 3         19.38283  ...        Entire villa  Entire home/apt         1 bath
# 4         19.41162  ...         Entire home  Entire home/apt      5.5 baths
# ...            ...  ...                 ...              ...            ...
# 24219  19.41121012  ...  Entire rental unit  Entire home/apt         1 bath
# 24221  19.39666335  ...  Entire rental unit  Entire home/apt         1 bath
# 24222  19.39202345  ...  Entire rental unit  Entire home/apt         1 bath
# 24224   19.4037919  ...  Entire rental unit  Entire home/apt         1 bath
# 24225  19.42628282  ...  Entire rental unit  Entire home/apt         1 bath
#
#                                                amenities    price  \
# 0      ["Wifi", "Hangers", "Fire extinguisher", "Sham...   1434.0
# 1      ["Free street parking", "Cleaning products", "...    830.0
# 2      ["Wifi \u2013 38 Mbps", "Central air condition...   1469.0
# 3      ["Wifi", "Washer", "BBQ grill", "Indoor firepl...   3658.0
# 4      ["Free street parking", "Security cameras on p...  18000.0
# ...                                                  ...      ...
# 24219  ["Clothing storage: closet and dresser", "Smok...    980.0
# 24221  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...    760.0
# 24222  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...   1520.0
# 24224  ["Smoke alarm", "Free street parking", "Condit...   1200.0
# 24225  ["Long term stays allowed", "Cleaning products...   1720.0
#
#       has_availability calendar_last_scraped first_review last_review  \
# 0                    t              30/03/23     03/01/14    24/06/18
# 1                    t              30/03/23     01/01/14    04/11/22
# 2                    t              29/03/23     31/10/12    21/12/22
# 3                    t              29/03/23     31/10/12    21/12/22
# 4                    t              30/03/23     09/11/11    26/03/23
# ...                ...                   ...          ...         ...
# 24219                t              29/03/23     29/03/23    29/03/23
# 24221                t              30/03/23     29/03/23    29/03/23
# 24222                t              29/03/23     29/03/23    29/03/23
# 24224                t              30/03/23     29/03/23    29/03/23
# 24225                t              30/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 0                    f
# 1                    f
# 2                    f
# 3                    f
# 4                    f
# ...                ...
# 24219                t
# 24221                f
# 24222                t
# 24224                t
# 24225                t
#
# [15601 rows x 75 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro2)
sns.scatterplot(x='number_of_reviews', y='Predicciones 3', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.019226689619606607

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.1386603390288896

# %% [markdown]
# ## **"review scores location vs review scores cleanliness"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro2)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['review_scores_cleanliness']]
Var_Dep= filtro2['review_scores_location']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.22239747]),
#  'rank_': 1,
#  'singular_': array([18.94945431]),
#  'intercept_': 3.8143792338293734}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.0863889486352889

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['review_scores_cleanliness']])
y_pred
# Out:
# array([4.91524669, 4.89967887, 4.8618713 , ..., 4.85964733, 4.85964733,
#        4.85964733])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 4', y_pred)
filtro2
# Out:
#        Predicciones 4  Predicciones 3  Predicciones 2  Predicciones  \
# 0            4.915247       93.279080       93.494498      95.05751
# 1            4.899679       97.344517       93.492404      95.05751
# 2            4.861871       95.108526       93.494620      95.05751
# 3            4.859647       91.144726       93.502211      95.05751
# 4            4.859647       97.649424       93.551949      95.05751
# ...               ...             ...             ...           ...
# 24219        4.859647       91.144726       93.492924      95.05751
# 24221        4.859647       91.144726       93.492161      95.05751
# 24222        4.859647       91.144726       93.494796      95.05751
# 24224        4.859647       91.144726       93.493687      95.05751
# 24225        4.859647       91.144726       93.495490      95.05751
#
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 1             1.0      2072354  2.02303E+13   16840050                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# ...           ...          ...          ...        ...                 ...
# 24219     24217.0   8.5379E+17  2.02303E+13   29239005                   3
# 24221     24219.0  8.53924E+17  2.02303E+13  488030249                   3
# 24222     24220.0  8.53967E+17  2.02303E+13  506816029                   1
# 24224     24222.0  8.54248E+17  2.02303E+13    7799414                  13
# 24225     24223.0   8.5426E+17  2.02303E+13  506864314                   2
#
#       host_total_listings_count  ...       property_type        room_type  \
# 0                             7  ...         Entire loft  Entire home/apt
# 1                             3  ...  Entire guest suite  Entire home/apt
# 2                             4  ...  Entire rental unit  Entire home/apt
# 3                             1  ...        Entire villa  Entire home/apt
# 4                            16  ...         Entire home  Entire home/apt
# ...                         ...  ...                 ...              ...
# 24219                         3  ...  Entire rental unit  Entire home/apt
# 24221                         4  ...  Entire rental unit  Entire home/apt
# 24222                         1  ...  Entire rental unit  Entire home/apt
# 24224                        13  ...  Entire rental unit  Entire home/apt
# 24225                         2  ...  Entire rental unit  Entire home/apt
#
#       bathrooms_text                                          amenities  \
# 0          1.5 baths  ["Wifi", "Hangers", "Fire extinguisher", "Sham...
# 1             1 bath  ["Free street parking", "Cleaning products", "...
# 2            2 baths  ["Wifi \u2013 38 Mbps", "Central air condition...
# 3             1 bath  ["Wifi", "Washer", "BBQ grill", "Indoor firepl...
# 4          5.5 baths  ["Free street parking", "Security cameras on p...
# ...              ...                                                ...
# 24219         1 bath  ["Clothing storage: closet and dresser", "Smok...
# 24221         1 bath  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...
# 24222         1 bath  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...
# 24224         1 bath  ["Smoke alarm", "Free street parking", "Condit...
# 24225         1 bath  ["Long term stays allowed", "Cleaning products...
#
#          price has_availability calendar_last_scraped first_review  \
# 0       1434.0                t              30/03/23     03/01/14
# 1        830.0                t              30/03/23     01/01/14
# 2       1469.0                t              29/03/23     31/10/12
# 3       3658.0                t              29/03/23     31/10/12
# 4      18000.0                t              30/03/23     09/11/11
# ...        ...              ...                   ...          ...
# 24219    980.0                t              29/03/23     29/03/23
# 24221    760.0                t              30/03/23     29/03/23
# 24222   1520.0                t              29/03/23     29/03/23
# 24224   1200.0                t              30/03/23     29/03/23
# 24225   1720.0                t              30/03/23     29/03/23
#
#       last_review instant_bookable
# 0        24/06/18                f
# 1        04/11/22                f
# 2        21/12/22                f
# 3        21/12/22                f
# 4        26/03/23                f
# ...           ...              ...
# 24219    29/03/23                t
# 24221    29/03/23                f
# 24222    29/03/23                t
# 24224    29/03/23                t
# 24225    29/03/23                t
#
# [15601 rows x 76 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro2)
sns.scatterplot(x='review_scores_cleanliness', y='Predicciones 4', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.0863889486352889

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.29391996977968154

# %% [markdown]
# ## **"availability_365 vs number _of reviews"**

# %%
filtro2.availability_365 = filtro2.availability_365.astype(str)
# Out:
# <ipython-input-603-73af74e8f07e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro2.availability_365 = filtro2.availability_365.astype(str)

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro2)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['number_of_reviews']]
Var_Dep= filtro2['availability_365']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.31734579]),
#  'rank_': 1,
#  'singular_': array([3043.24765506]),
#  'intercept_': 248.07436841784084}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.003939867761715066

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['number_of_reviews']])
y_pred
# Out:
# array([241.41010677, 228.71627507, 235.69788251, ..., 248.07436842,
#        248.07436842, 248.07436842])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 5', y_pred)
filtro2
# Out:
#        Predicciones 5  Predicciones 4  Predicciones 3  Predicciones 2  \
# 0          241.410107        4.915247       93.279080       93.494498
# 1          228.716275        4.899679       97.344517       93.492404
# 2          235.697883        4.861871       95.108526       93.494620
# 3          248.074368        4.859647       91.144726       93.502211
# 4          227.764238        4.859647       97.649424       93.551949
# ...               ...             ...             ...             ...
# 24219      248.074368        4.859647       91.144726       93.492924
# 24221      248.074368        4.859647       91.144726       93.492161
# 24222      248.074368        4.859647       91.144726       93.494796
# 24224      248.074368        4.859647       91.144726       93.493687
# 24225      248.074368        4.859647       91.144726       93.495490
#
#        Predicciones  Unnamed: 0           id    scrape_id    host_id  \
# 0          95.05751         0.0      2056638  2.02303E+13   10531228
# 1          95.05751         1.0      2072354  2.02303E+13   16840050
# 2          95.05751         2.0       696037  2.02303E+13    3531879
# 3          95.05751         3.0        35797  2.02303E+13     153786
# 4          95.05751         4.0        44616  2.02303E+13     196253
# ...             ...         ...          ...          ...        ...
# 24219      95.05751     24217.0   8.5379E+17  2.02303E+13   29239005
# 24221      95.05751     24219.0  8.53924E+17  2.02303E+13  488030249
# 24222      95.05751     24220.0  8.53967E+17  2.02303E+13  506816029
# 24224      95.05751     24222.0  8.54248E+17  2.02303E+13    7799414
# 24225      95.05751     24223.0   8.5426E+17  2.02303E+13  506864314
#
#       host_listings_count  ...       property_type        room_type  \
# 0                       3  ...         Entire loft  Entire home/apt
# 1                       3  ...  Entire guest suite  Entire home/apt
# 2                       4  ...  Entire rental unit  Entire home/apt
# 3                       1  ...        Entire villa  Entire home/apt
# 4                      16  ...         Entire home  Entire home/apt
# ...                   ...  ...                 ...              ...
# 24219                   3  ...  Entire rental unit  Entire home/apt
# 24221                   3  ...  Entire rental unit  Entire home/apt
# 24222                   1  ...  Entire rental unit  Entire home/apt
# 24224                  13  ...  Entire rental unit  Entire home/apt
# 24225                   2  ...  Entire rental unit  Entire home/apt
#
#       bathrooms_text                                          amenities  \
# 0          1.5 baths  ["Wifi", "Hangers", "Fire extinguisher", "Sham...
# 1             1 bath  ["Free street parking", "Cleaning products", "...
# 2            2 baths  ["Wifi \u2013 38 Mbps", "Central air condition...
# 3             1 bath  ["Wifi", "Washer", "BBQ grill", "Indoor firepl...
# 4          5.5 baths  ["Free street parking", "Security cameras on p...
# ...              ...                                                ...
# 24219         1 bath  ["Clothing storage: closet and dresser", "Smok...
# 24221         1 bath  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...
# 24222         1 bath  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...
# 24224         1 bath  ["Smoke alarm", "Free street parking", "Condit...
# 24225         1 bath  ["Long term stays allowed", "Cleaning products...
#
#          price has_availability calendar_last_scraped first_review  \
# 0       1434.0                t              30/03/23     03/01/14
# 1        830.0                t              30/03/23     01/01/14
# 2       1469.0                t              29/03/23     31/10/12
# 3       3658.0                t              29/03/23     31/10/12
# 4      18000.0                t              30/03/23     09/11/11
# ...        ...              ...                   ...          ...
# 24219    980.0                t              29/03/23     29/03/23
# 24221    760.0                t              30/03/23     29/03/23
# 24222   1520.0                t              29/03/23     29/03/23
# 24224   1200.0                t              30/03/23     29/03/23
# 24225   1720.0                t              30/03/23     29/03/23
#
#       last_review instant_bookable
# 0        24/06/18                f
# 1        04/11/22                f
# 2        21/12/22                f
# 3        21/12/22                f
# 4        26/03/23                f
# ...           ...              ...
# 24219    29/03/23                t
# 24221    29/03/23                f
# 24222    29/03/23                t
# 24224    29/03/23                t
# 24225    29/03/23                t
#
# [15601 rows x 77 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro2)
sns.scatterplot(x='number_of_reviews', y='Predicciones 5', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.003939867761715066

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.06276836593153486

# %% [markdown]
# ## **"reviews_per_month vs review_scores_communication"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro2)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['review_scores_communication']]
Var_Dep= filtro2['reviews_per_month']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.87165186]),
#  'rank_': 1,
#  'singular_': array([14.12421852]),
#  'intercept_': 5.824808105790648}

# %% [markdown]
# **Modelo matemático**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.00882494419096902

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['review_scores_communication']])
y_pred
# Out:
# array([1.51013138, 1.46654879, 1.53628094, ..., 1.64087916, 1.64087916,
#        1.64087916])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 6', y_pred)
filtro2
# Out:
#        Predicciones 6  Predicciones 5  Predicciones 4  Predicciones 3  \
# 0            1.510131      241.410107        4.915247       93.279080
# 1            1.466549      228.716275        4.899679       97.344517
# 2            1.536281      235.697883        4.861871       95.108526
# 3            1.640879      248.074368        4.859647       91.144726
# 4            1.658312      227.764238        4.859647       97.649424
# ...               ...             ...             ...             ...
# 24219        1.640879      248.074368        4.859647       91.144726
# 24221        1.640879      248.074368        4.859647       91.144726
# 24222        1.640879      248.074368        4.859647       91.144726
# 24224        1.640879      248.074368        4.859647       91.144726
# 24225        1.640879      248.074368        4.859647       91.144726
#
#        Predicciones 2  Predicciones  Unnamed: 0           id    scrape_id  \
# 0           93.494498      95.05751         0.0      2056638  2.02303E+13
# 1           93.492404      95.05751         1.0      2072354  2.02303E+13
# 2           93.494620      95.05751         2.0       696037  2.02303E+13
# 3           93.502211      95.05751         3.0        35797  2.02303E+13
# 4           93.551949      95.05751         4.0        44616  2.02303E+13
# ...               ...           ...         ...          ...          ...
# 24219       93.492924      95.05751     24217.0   8.5379E+17  2.02303E+13
# 24221       93.492161      95.05751     24219.0  8.53924E+17  2.02303E+13
# 24222       93.494796      95.05751     24220.0  8.53967E+17  2.02303E+13
# 24224       93.493687      95.05751     24222.0  8.54248E+17  2.02303E+13
# 24225       93.495490      95.05751     24223.0   8.5426E+17  2.02303E+13
#
#          host_id  ...       property_type        room_type bathrooms_text  \
# 0       10531228  ...         Entire loft  Entire home/apt      1.5 baths
# 1       16840050  ...  Entire guest suite  Entire home/apt         1 bath
# 2        3531879  ...  Entire rental unit  Entire home/apt        2 baths
# 3         153786  ...        Entire villa  Entire home/apt         1 bath
# 4         196253  ...         Entire home  Entire home/apt      5.5 baths
# ...          ...  ...                 ...              ...            ...
# 24219   29239005  ...  Entire rental unit  Entire home/apt         1 bath
# 24221  488030249  ...  Entire rental unit  Entire home/apt         1 bath
# 24222  506816029  ...  Entire rental unit  Entire home/apt         1 bath
# 24224    7799414  ...  Entire rental unit  Entire home/apt         1 bath
# 24225  506864314  ...  Entire rental unit  Entire home/apt         1 bath
#
#                                                amenities    price  \
# 0      ["Wifi", "Hangers", "Fire extinguisher", "Sham...   1434.0
# 1      ["Free street parking", "Cleaning products", "...    830.0
# 2      ["Wifi \u2013 38 Mbps", "Central air condition...   1469.0
# 3      ["Wifi", "Washer", "BBQ grill", "Indoor firepl...   3658.0
# 4      ["Free street parking", "Security cameras on p...  18000.0
# ...                                                  ...      ...
# 24219  ["Clothing storage: closet and dresser", "Smok...    980.0
# 24221  ["Smoke alarm", "Wifi", "Iron", "Washer", "Sel...    760.0
# 24222  ["Lake access", "Ski-in/Ski-out", "Wifi", "Out...   1520.0
# 24224  ["Smoke alarm", "Free street parking", "Condit...   1200.0
# 24225  ["Long term stays allowed", "Cleaning products...   1720.0
#
#       has_availability calendar_last_scraped first_review last_review  \
# 0                    t              30/03/23     03/01/14    24/06/18
# 1                    t              30/03/23     01/01/14    04/11/22
# 2                    t              29/03/23     31/10/12    21/12/22
# 3                    t              29/03/23     31/10/12    21/12/22
# 4                    t              30/03/23     09/11/11    26/03/23
# ...                ...                   ...          ...         ...
# 24219                t              29/03/23     29/03/23    29/03/23
# 24221                t              30/03/23     29/03/23    29/03/23
# 24222                t              29/03/23     29/03/23    29/03/23
# 24224                t              30/03/23     29/03/23    29/03/23
# 24225                t              30/03/23     29/03/23    29/03/23
#
#       instant_bookable
# 0                    f
# 1                    f
# 2                    f
# 3                    f
# 4                    f
# ...                ...
# 24219                t
# 24221                f
# 24222                t
# 24224                t
# 24225                t
#
# [15601 rows x 78 columns]

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro2)
sns.scatterplot(x='review_scores_communication', y='Predicciones 6', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.00882494419096902

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.09394117409831015
