# %% [markdown]
# <a href="https://colab.research.google.com/github/caroSF1/Regresi-n-Lineal/blob/main/EUA_Act_6_1_Regresi%C3%B3n_Lineal_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Act 6.1 Regresión Lineal Simple Estados Unidos**
# ## **Carolina Solis Flores**
# ## **A01708072**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("DatosEUA_limpios.csv")
df.head()
# Out:
#    Unnamed: 0   ï»¿id     scrape_id  host_id  host_listings_count  \
# 0           0   958.0  2.020000e+13   1169.0                  1.0
# 1           1  5858.0  2.020000e+13   8904.0                  2.0
# 2           2  8142.0  2.020000e+13  21994.0                 13.0
# 3           3  8339.0  2.020000e+13  24215.0                  2.0
# 4           4  8739.0  2.020000e+13   7149.0                  2.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bedrooms  \
# 0                        1.0  37.77028 -122.43317             3       1.0
# 1                        2.0  37.74474 -122.42089             4       2.0
# 2                       14.0  37.76555 -122.45213             1       1.0
# 3                        6.0  37.77564 -122.43642             4       2.0
# 4                        2.0  37.76030 -122.42197             3       1.0
#
#    ...        room_type  bathrooms_text  \
# 0  ...  Entire home/apt          1 bath
# ...

# %% [markdown]
# # **Filtro 1**

# %%
filtro1=df[df["room_type"] == "Private room"]
filtro1
# Out:
#       Unnamed: 0       ï»¿id     scrape_id      host_id  host_listings_count  \
# 2              2      8142.0  2.020000e+13      21994.0                 13.0
# 4              4      8739.0  2.020000e+13       7149.0                  2.0
# 6              6    490931.0  2.020000e+13    1269188.0                  1.0
# 7              7     10537.0  2.020000e+13      36752.0                  2.0
# 11            11    144978.0  2.020000e+13     216682.0                  9.0
# ...          ...         ...           ...          ...                  ...
# 6927        6927  27790615.3  2.020000e+13   87507815.4                 32.0
# 6929        6929  27790615.3  2.020000e+13  226555948.0                  5.3
# 6930        6930  27790615.3  2.020000e+13  286802480.0                  6.0
# 6933        6933  27790615.3  2.020000e+13   87507815.4                  1.0
# 6934        6934  27790615.3  2.020000e+13   87507815.4                  3.0
#
# ...

# %% [markdown]
# ## **"host acceptance rate vs host response rate"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['host_response_rate']]
Var_Dep= filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.16574039]),
#  'rank_': 1,
#  'singular_': array([954.20046674]),
#  'intercept_': 74.23181527158503}

# %% [markdown]
# **Modelo matemático: y= 0.16574039 + 74.23181527158503**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.025609933442360844

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['host_response_rate']])
y_pred
# Out:
# array([90.80585389, 90.80585389, 90.80585389, ..., 90.80585389,
#        90.80585389, 90.80585389])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones', y_pred)
filtro1
# Out:
#       Predicciones  Unnamed: 0       ï»¿id     scrape_id      host_id  \
# 2        90.805854           2      8142.0  2.020000e+13      21994.0
# 4        90.805854           4      8739.0  2.020000e+13       7149.0
# 6        90.805854           6    490931.0  2.020000e+13    1269188.0
# 7        90.805854           7     10537.0  2.020000e+13      36752.0
# 11       90.805854          11    144978.0  2.020000e+13     216682.0
# ...            ...         ...         ...           ...          ...
# 6927     90.805854        6927  27790615.3  2.020000e+13   87507815.4
# 6929     90.805854        6929  27790615.3  2.020000e+13  226555948.0
# 6930     90.805854        6930  27790615.3  2.020000e+13  286802480.0
# 6933     90.805854        6933  27790615.3  2.020000e+13   87507815.4
# 6934     90.805854        6934  27790615.3  2.020000e+13   87507815.4
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro1)
sns.scatterplot(x='host_response_rate', y='Predicciones', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.025609933442360844

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.16003103899669227

# %% [markdown]
# ## **"host_acceptance_rate vs price"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['price']]
Var_Dep= filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.00043802]),
#  'rank_': 1,
#  'singular_': array([97252.31505148]),
#  'intercept_': 89.90749448403163}

# %% [markdown]
# **Modelo matemático: y= -0.00043802x + 89.90749448403163**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.0018580767213612903

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['price']])
y_pred
# Out:
# array([89.88296527, 89.8593121 , 89.86369231, ..., 89.88296527,
#        89.86194023, 89.87902307])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 2', y_pred)
filtro1
# Out:
#       Predicciones 2  Predicciones  Unnamed: 0       ï»¿id     scrape_id  \
# 2          89.882965     90.805854           2      8142.0  2.020000e+13
# 4          89.859312     90.805854           4      8739.0  2.020000e+13
# 6          89.863692     90.805854           6    490931.0  2.020000e+13
# 7          89.865882     90.805854           7     10537.0  2.020000e+13
# 11         89.883403     90.805854          11    144978.0  2.020000e+13
# ...              ...           ...         ...         ...           ...
# 6927       89.872453     90.805854        6927  27790615.3  2.020000e+13
# 6929       89.889974     90.805854        6929  27790615.3  2.020000e+13
# 6930       89.882965     90.805854        6930  27790615.3  2.020000e+13
# 6933       89.861940     90.805854        6933  27790615.3  2.020000e+13
# 6934       89.879023     90.805854        6934  27790615.3  2.020000e+13
#
#           host_id  host_listings_count  host_total_listings_count   latitude  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro1)
sns.scatterplot(x='price', y='Predicciones 2', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.0018580767213612903

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.043105414060896

# %% [markdown]
# ## **"host_acceptance_rate vs number_of_reviews"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= filtro1[['number_of_reviews']]
Var_Dep= filtro1['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.09417798]),
#  'rank_': 1,
#  'singular_': array([1293.36559786]),
#  'intercept_': 87.86264110678027}

# %% [markdown]
# **Modelo matemático: y= 0.09417798x + 87.86264110678027**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.015191962739025566

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['number_of_reviews']])
y_pred
# Out:
# array([88.71024295, 89.60493379, 95.39687974, ..., 87.86264111,
#        87.86264111, 87.86264111])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 3', y_pred)
filtro1
# Out:
#       Predicciones 3  Predicciones 2  Predicciones  Unnamed: 0       ï»¿id  \
# 2          88.710243       89.882965     90.805854           2      8142.0
# 4          89.604934       89.859312     90.805854           4      8739.0
# 6          95.396880       89.863692     90.805854           6    490931.0
# 7          89.652023       89.865882     90.805854           7     10537.0
# 11         89.604934       89.883403     90.805854          11    144978.0
# ...              ...             ...           ...         ...         ...
# 6927       87.956819       89.872453     90.805854        6927  27790615.3
# 6929       87.862641       89.889974     90.805854        6929  27790615.3
# 6930       87.862641       89.882965     90.805854        6930  27790615.3
# 6933       87.862641       89.861940     90.805854        6933  27790615.3
# 6934       87.862641       89.879023     90.805854        6934  27790615.3
#
#          scrape_id      host_id  host_listings_count  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro1)
sns.scatterplot(x='number_of_reviews', y='Predicciones 3', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.015191962739025566

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.12325568035196417

# %% [markdown]
# ## **"review scores location vs review scores cleanliness"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['review_scores_cleanliness']]
Var_Dep= filtro1['review_scores_location']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.21919069]),
#  'rank_': 1,
#  'singular_': array([6.52798736]),
#  'intercept_': 3.7904781620385815}

# %% [markdown]
# **Modelo matemático: y= 0.21919069x + 3.7904781620385815**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.05886023394665352

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['review_scores_cleanliness']])
y_pred
# Out:
# array([4.86451256, 4.87328019, 4.83163396, ..., 4.84259349, 4.84259349,
#        4.84259349])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 4', y_pred)
filtro1
# Out:
#       Predicciones 4  Predicciones 3  Predicciones 2  Predicciones  \
# 2           4.864513       88.710243       89.882965     90.805854
# 4           4.873280       89.604934       89.859312     90.805854
# 6           4.831634       95.396880       89.863692     90.805854
# 7           4.886432       89.652023       89.865882     90.805854
# 11          4.864513       89.604934       89.883403     90.805854
# ...              ...             ...             ...           ...
# 6927        4.886432       87.956819       89.872453     90.805854
# 6929        4.842593       87.862641       89.889974     90.805854
# 6930        4.842593       87.862641       89.882965     90.805854
# 6933        4.842593       87.862641       89.861940     90.805854
# 6934        4.842593       87.862641       89.879023     90.805854
#
#       Unnamed: 0       ï»¿id     scrape_id      host_id  host_listings_count  \
# 2              2      8142.0  2.020000e+13      21994.0                 13.0
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro1)
sns.scatterplot(x='review_scores_cleanliness', y='Predicciones 4', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.05886023394665352

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.2426112815733298

# %% [markdown]
# ## **"availability_365 vs number _of reviews"**

# %%
filtro1.availability_365 = filtro1.availability_365.astype(str)
# Out:
# <ipython-input-53-b6f2c2b9c89b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro1.availability_365 = filtro1.availability_365.astype(str)

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['number_of_reviews']]
Var_Dep= filtro1['availability_365']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.54646752]),
#  'rank_': 1,
#  'singular_': array([1293.36559786]),
#  'intercept_': 188.0818615846327}

# %% [markdown]
# **Modelo matemático: y=-0.54646752x + 188.0818615846327**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.011576045280019986

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['number_of_reviews']])
y_pred
# Out:
# array([183.16365389, 177.97221244, 144.36445988, ..., 188.08186158,
#        188.08186158, 188.08186158])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 5', y_pred)
filtro1
# Out:
#       Predicciones 5  Predicciones 4  Predicciones 3  Predicciones 2  \
# 2         183.163654        4.864513       88.710243       89.882965
# 4         177.972212        4.873280       89.604934       89.859312
# 6         144.364460        4.831634       95.396880       89.863692
# 7         177.698979        4.886432       89.652023       89.865882
# 11        177.972212        4.864513       89.604934       89.883403
# ...              ...             ...             ...             ...
# 6927      187.535394        4.886432       87.956819       89.872453
# 6929      188.081862        4.842593       87.862641       89.889974
# 6930      188.081862        4.842593       87.862641       89.882965
# 6933      188.081862        4.842593       87.862641       89.861940
# 6934      188.081862        4.842593       87.862641       89.879023
#
#       Predicciones  Unnamed: 0       ï»¿id     scrape_id      host_id  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro1)
sns.scatterplot(x='number_of_reviews', y='Predicciones 5', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.011576045280019986

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.1075920316753057

# %% [markdown]
# ## **"reviews_per_month vs review_scores_communication"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro1)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro1[['review_scores_communication']]
Var_Dep= filtro1['reviews_per_month']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-2.59817328]),
#  'rank_': 1,
#  'singular_': array([2.75086697]),
#  'intercept_': 13.69900832582132}

# %% [markdown]
# **Modelo matemático: y= -2.59817328 + 13.69900832582132**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.04916788769117619

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro1[['review_scores_communication']])
y_pred
# Out:
# array([1.27974006, 0.81206887, 1.27974006, ..., 0.96795927, 0.96795927,
#        0.96795927])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro1.insert(0, 'Predicciones 6', y_pred)
filtro1
# Out:
#       Predicciones 6  Predicciones 5  Predicciones 4  Predicciones 3  \
# 2           1.279740      183.163654        4.864513       88.710243
# 4           0.812069      177.972212        4.873280       89.604934
# 6           1.279740      144.364460        4.831634       95.396880
# 7           0.708142      177.698979        4.886432       89.652023
# 11          1.201795      177.972212        4.864513       89.604934
# ...              ...             ...             ...             ...
# 6927        0.708142      187.535394        4.886432       87.956819
# 6929        0.967959      188.081862        4.842593       87.862641
# 6930        0.967959      188.081862        4.842593       87.862641
# 6933        0.967959      188.081862        4.842593       87.862641
# 6934        0.967959      188.081862        4.842593       87.862641
#
#       Predicciones 2  Predicciones  Unnamed: 0       ï»¿id     scrape_id  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro1)
sns.scatterplot(x='review_scores_communication', y='Predicciones 6', color="red", data=filtro1)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.04916788769117619

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.22173833157840842

# %% [markdown]
# # **Filtro 2**

# %%
filtro2=df[df["room_type"] == "Entire home/apt"]
filtro2
# Out:
#       Unnamed: 0       ï»¿id     scrape_id     host_id  host_listings_count  \
# 0              0       958.0  2.020000e+13      1169.0                  1.0
# 1              1      5858.0  2.020000e+13      8904.0                  2.0
# 3              3      8339.0  2.020000e+13     24215.0                  2.0
# 5              5    142177.0  2.020000e+13    656263.0                  1.0
# 8              8    491867.0  2.020000e+13    969518.0                  2.0
# ...          ...         ...           ...         ...                  ...
# 6923        6923  27790615.3  2.020000e+13   4452428.0                  3.0
# 6928        6928  27790615.3  2.020000e+13   9835117.0                  2.0
# 6931        6931  27790615.3  2.020000e+13  87507815.4                  9.0
# 6932        6932  27790615.3  2.020000e+13  87507815.4                  1.0
# 6935        6935  27790615.3  2.020000e+13   4836128.0                  2.0
#
# ...

# %% [markdown]
# ## **"host acceptance rate vs host response rate"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro2)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['host_response_rate']]
Var_Dep= filtro2['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.34415374]),
#  'rank_': 1,
#  'singular_': array([842.95421518]),
#  'intercept_': 53.700983501769976}

# %% [markdown]
# **Modelo matemático: y= 0.34415374x + 53.700983501769976**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.04293940673334218

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['host_response_rate']])
y_pred
# Out:
# array([88.11635796, 81.23328307, 88.11635796, ..., 88.11635796,
#        88.11635796, 88.11635796])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones', y_pred)
filtro2
# Out:
#       Predicciones  Unnamed: 0       ï»¿id     scrape_id     host_id  \
# 0        88.116358           0       958.0  2.020000e+13      1169.0
# 1        81.233283           1      5858.0  2.020000e+13      8904.0
# 3        88.116358           3      8339.0  2.020000e+13     24215.0
# 5        88.116358           5    142177.0  2.020000e+13    656263.0
# 8        88.116358           8    491867.0  2.020000e+13    969518.0
# ...            ...         ...         ...           ...         ...
# 6923     88.116358        6923  27790615.3  2.020000e+13   4452428.0
# 6928     88.116358        6928  27790615.3  2.020000e+13   9835117.0
# 6931     88.116358        6931  27790615.3  2.020000e+13  87507815.4
# 6932     88.116358        6932  27790615.3  2.020000e+13  87507815.4
# 6935     88.116358        6935  27790615.3  2.020000e+13   4836128.0
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=filtro2)
sns.scatterplot(x='host_response_rate', y='Predicciones', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.04293940673334218

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.20721825868716826

# %% [markdown]
# ## **"host_acceptance_rate vs price"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro2)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['price']]
Var_Dep= filtro2['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.0009132]),
#  'rank_': 1,
#  'singular_': array([35440.1013724]),
#  'intercept_': 87.2819801108436}

# %% [markdown]
# **Modelo matemático: y= -0.0009132x + 87.2819801108436**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.0005343974621976333

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['price']])
y_pred
# Out:
# array([87.0975138 , 87.06737821, 86.75689035, ..., 87.13221538,
#        87.07377061, 86.93953027])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 2', y_pred)
filtro2
# Out:
#       Predicciones 2  Predicciones  Unnamed: 0       ï»¿id     scrape_id  \
# 0          87.097514     88.116358           0       958.0  2.020000e+13
# 1          87.067378     81.233283           1      5858.0  2.020000e+13
# 3          86.756890     88.116358           3      8339.0  2.020000e+13
# 5          87.045461     88.116358           5    142177.0  2.020000e+13
# 8          86.893870     88.116358           8    491867.0  2.020000e+13
# ...              ...           ...         ...         ...           ...
# 6923       87.181528     88.116358        6923  27790615.3  2.020000e+13
# 6928       87.122170     88.116358        6928  27790615.3  2.020000e+13
# 6931       87.132215     88.116358        6931  27790615.3  2.020000e+13
# 6932       87.073771     88.116358        6932  27790615.3  2.020000e+13
# 6935       86.939530     88.116358        6935  27790615.3  2.020000e+13
#
#          host_id  host_listings_count  host_total_listings_count   latitude  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=filtro2)
sns.scatterplot(x='price', y='Predicciones 2', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.0005343974621976333

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.023117038352644427

# %% [markdown]
# ## **"host_acceptance_rate vs number_of_reviews"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro2)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= filtro2[['number_of_reviews']]
Var_Dep= filtro2['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.07693966]),
#  'rank_': 1,
#  'singular_': array([1660.39014988]),
#  'intercept_': 85.67040193420279}

# %% [markdown]
# **Modelo matemático: y= 0.07693966x + 85.67040193420279**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.008326525889989167

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['number_of_reviews']])
y_pred
# Out:
# array([87.09378556, 94.21070367, 87.82471228, ..., 85.67040193,
#        85.74734159, 85.67040193])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 3', y_pred)
filtro2
# Out:
#       Predicciones 3  Predicciones 2  Predicciones  Unnamed: 0       ï»¿id  \
# 0          87.093786       87.097514     88.116358           0       958.0
# 1          94.210704       87.067378     81.233283           1      5858.0
# 3          87.824712       86.756890     88.116358           3      8339.0
# 5          87.093786       87.045461     88.116358           5    142177.0
# 8          89.979023       86.893870     88.116358           8    491867.0
# ...              ...             ...           ...         ...         ...
# 6923       85.670402       87.181528     88.116358        6923  27790615.3
# 6928       85.670402       87.122170     88.116358        6928  27790615.3
# 6931       85.670402       87.132215     88.116358        6931  27790615.3
# 6932       85.747342       87.073771     88.116358        6932  27790615.3
# 6935       85.670402       86.939530     88.116358        6935  27790615.3
#
#          scrape_id     host_id  host_listings_count  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=filtro2)
sns.scatterplot(x='number_of_reviews', y='Predicciones 3', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.008326525889989167

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.09124979939698041

# %% [markdown]
# ## **"review scores location vs review scores cleanliness"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro2)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['review_scores_cleanliness']]
Var_Dep= filtro2['review_scores_location']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.28407303]),
#  'rank_': 1,
#  'singular_': array([8.17601471]),
#  'intercept_': 3.493227245904711}

# %% [markdown]
# **Modelo matemático: y= 0.28407303x + 3.493227245904711**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.09189625729375195

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['review_scores_cleanliness']])
y_pred
# Out:
# array([4.89086654, 4.87666289, 4.91359238, ..., 4.85677778, 4.91359238,
#        4.85677778])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 4', y_pred)
filtro2
# Out:
#       Predicciones 4  Predicciones 3  Predicciones 2  Predicciones  \
# 0           4.890867       87.093786       87.097514     88.116358
# 1           4.876663       94.210704       87.067378     81.233283
# 3           4.913592       87.824712       86.756890     88.116358
# 5           4.879504       87.093786       87.045461     88.116358
# 8           4.873822       89.979023       86.893870     88.116358
# ...              ...             ...             ...           ...
# 6923        4.856778       85.670402       87.181528     88.116358
# 6928        4.856778       85.670402       87.122170     88.116358
# 6931        4.856778       85.670402       87.132215     88.116358
# 6932        4.913592       85.747342       87.073771     88.116358
# 6935        4.856778       85.670402       86.939530     88.116358
#
#       Unnamed: 0       ï»¿id     scrape_id     host_id  host_listings_count  \
# 0              0       958.0  2.020000e+13      1169.0                  1.0
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=filtro2)
sns.scatterplot(x='review_scores_cleanliness', y='Predicciones 4', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.09189625729375195

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.3031439547372699

# %% [markdown]
# ## **"availability_365 vs number _of reviews"**

# %%
filtro2.availability_365 = filtro2.availability_365.astype(str)
# Out:
# <ipython-input-127-73af74e8f07e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro2.availability_365 = filtro2.availability_365.astype(str)

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro2)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['number_of_reviews']]
Var_Dep= filtro2['availability_365']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.5260898]),
#  'rank_': 1,
#  'singular_': array([1660.39014988]),
#  'intercept_': 175.20140936357382}

# %% [markdown]
# **Modelo matemático: y= -0.5260898]x + 175.20140936357382**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.01097685507017565

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['number_of_reviews']])
y_pred
# Out:
# array([165.46874816, 116.80544211, 160.4708951 , ..., 175.20140936,
#        174.67531957, 175.20140936])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 5', y_pred)
filtro2
# Out:
#       Predicciones 5  Predicciones 4  Predicciones 3  Predicciones 2  \
# 0         165.468748        4.890867       87.093786       87.097514
# 1         116.805442        4.876663       94.210704       87.067378
# 3         160.470895        4.913592       87.824712       86.756890
# 5         165.468748        4.879504       87.093786       87.045461
# 8         145.740381        4.873822       89.979023       86.893870
# ...              ...             ...             ...             ...
# 6923      175.201409        4.856778       85.670402       87.181528
# 6928      175.201409        4.856778       85.670402       87.122170
# 6931      175.201409        4.856778       85.670402       87.132215
# 6932      174.675320        4.913592       85.747342       87.073771
# 6935      175.201409        4.856778       85.670402       86.939530
#
#       Predicciones  Unnamed: 0       ï»¿id     scrape_id     host_id  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=filtro2)
sns.scatterplot(x='number_of_reviews', y='Predicciones 5', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.01097685507017565

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.10477048759157156

# %% [markdown]
# ## **"reviews_per_month vs review_scores_communication"**

# %%
#Imprimimos el scatter plot entre la variable dependiente  e independiente
#para observar el comportamiento en su dispersión 
from turtle import color

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro2)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= filtro2[['review_scores_communication']]
Var_Dep= filtro2['reviews_per_month']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)  #X, es una matriz, y es un vector
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-2.74358085]),
#  'rank_': 1,
#  'singular_': array([3.6568836]),
#  'intercept_': 14.3771181440607}

# %% [markdown]
# **Modelo matemático: y= -2.74358085x + 14.3771181440607**
#
# ---

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.05396960716162358

# %%
#Predecimos los valores
y_pred= model.predict(X=filtro2[['review_scores_communication']])
y_pred
# Out:
# array([0.98844359, 1.07075102, 0.65921389, ..., 0.93357198, 0.65921389,
#        0.93357198])

# %%
#Insertamos la columna de predicciones en el DataFrame
filtro2.insert(0, 'Predicciones 6', y_pred)
filtro2
# Out:
#       Predicciones 6  Predicciones 5  Predicciones 4  Predicciones 3  \
# 0           0.988444      165.468748        4.890867       87.093786
# 1           1.070751      116.805442        4.876663       94.210704
# 3           0.659214      160.470895        4.913592       87.824712
# 5           0.741521      165.468748        4.879504       87.093786
# 8           0.906136      145.740381        4.873822       89.979023
# ...              ...             ...             ...             ...
# 6923        0.933572      175.201409        4.856778       85.670402
# 6928        0.933572      175.201409        4.856778       85.670402
# 6931        0.933572      175.201409        4.856778       85.670402
# 6932        0.659214      174.675320        4.913592       85.747342
# 6935        0.933572      175.201409        4.856778       85.670402
#
#       Predicciones 2  Predicciones  Unnamed: 0       ï»¿id     scrape_id  \
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=filtro2)
sns.scatterplot(x='review_scores_communication', y='Predicciones 6', color="red", data=filtro2)
#sns.lineplot(x='alcohol', y='Predicciones', color="red", data=df
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.05396960716162358

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.23231359659224335
